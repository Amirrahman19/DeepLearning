# %% [markdown]
# # Fashion MNIST Image Classification
# ## ST1504 Deep Learning CA1 Part A
#
# ##### Name: Haja Amir Rahman
# ##### Class: DAAA/FT/2B/06
# ##### Admin Number: P2100803
#
# ## References:
# - [Fashion-Mnist Dataset](https://www.tensorflow.org/api_docs/python/tf/keras/datasets/fashion_mnist/load_data)
# - [Keras Tuner](https://www.tensorflow.org/tutorials/keras/keras_tuner)
# - [Flipping & cropping images](https://www.tensorflow.org/api_docs/python/tf/image/flip_left_right)
#
# <h4><b>Notebook Contents:</b></h4>
# 1. Data Exploration/Background Research<br>
# 2. Data Augmentation/Feature Engineering<br>
# 3. Modelling & Evaluation<br>
# 4. Model Improvement<br>

# %% [markdown]
# <h3><b>1. Data Exploration/ Background Research</b></h3>
#
# The Fashion MNIST Dataset is a dataset of Zalando's images, with 60000 examples for training and 10000 examples for testing. Each example is a 28x28 greyscale image, with 10 associated labels.

# %% [markdown]
# * Import all modules
# * Load dataset
# * Rescale test and train images

# %%
import tensorflow as tf

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import keras
from tensorflow.keras.callbacks import EarlyStopping,  ReduceLROnPlateau
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
import seaborn as sns
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
from keras import layers
from tensorflow.keras import Sequential
from matplotlib import pyplot

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 
'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ## Train-test-split and Normalization

# %%
(x_train,y_train),(x_test,y_test)= tf.keras.datasets.fashion_mnist.load_data()
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train,test_size=0.1, shuffle=False)
x_test = x_test/255
x_val = x_val/255
x_train = x_train/255

# %%
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (54000, 28, 28) (54000,)
# (6000, 28, 28) (6000,)
# (10000, 28, 28) (10000,)

# %% [markdown]
# * 54000 images of 28 pixels by 28 pixels for training and 54000 labels to pair with the images
#
# * 6000 images of 28 x 28 for validation and 6000 labels
#
# * 10000 images of 28 pixels by 28 pixels for testing and 10000 labels to pair with the images

# %% [markdown]
# - 28x28 image loaded

# %%
plt.figure()
plt.imshow(x_test[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
# import matplotlib.pyplot as plt

# NUM_ROW = 6               # CHANGE THIS
# NUM_COL = 5               # CHANGE THIS
# WIDTH = 14                # CHANGE THIS
# HEIGHT = 14               # CHANGE THIS

# fig, ax = plt.subplots(NUM_ROW, NUM_COL, figsize=(WIDTH, HEIGHT))
# row_i = 0
# col_i = 0

# for i in range(30):        # CHANGE THIS

#     img = x_train[i]
#     label = y_train[i]
    
#     ax[row_i, col_i].imshow(img, cmap=plt.cm.binary)
#     ax[row_i, col_i].set_title(f"{class_names[label]}")
#     ax[row_i, col_i].axis("off")

#     col_i += 1
#     if col_i > NUM_COL-1:
#         row_i += 1
#         col_i = 0
        
# plt.show()

# %%
plt.figure(figsize=(15,15),facecolor="lightblue")
for i in range(64): # 64 imgs
  plt.subplot(8,8,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(x_train[i], cmap=plt.cm.binary) # printing binary/black and white image
  plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(x = y_train)
ax.set_xticklabels(class_names)
plt.show()

# %% [markdown]
# * Trainings images for each class are similar in number, no skewed training should occur
# * Dataset is balanced

# %% [markdown]
# <h2>Objectives/Tasks</h2>
#
# * Be able to accurately identify the test images fed to the model
# * Get highest possible accuracy and loss (>95% accuracy)
# * Use regularization methods, data augmentation and different model architecture to reduce overfitting while improving accuracy and loss

# %% [markdown]
# <h3><b>2. Data Augmentation</h3></b>

# %% [markdown]
# * Defined function to execute flipping and tilting on training images

# %%
plt.imshow(x_train[0])
plt.show()
plt.imshow(tf.image.flip_left_right(x_train[0].reshape((*x_train[0].shape,1))))
plt.show()

# %%
def flipall(images):
    images = images.reshape((*images.shape,1))
    images = tf.image.flip_left_right(images).numpy()
    images = images.reshape(images.shape[:3])

    return images
    
x_train_flipped = flipall(x_train)
print(x_train_flipped.shape)

WIDTH = 10                # CHANGE THIS
HEIGHT = 20               # CHANGE THIS

fig, ax = plt.subplots(10, 2, figsize=(WIDTH, HEIGHT))

for i in range(10):        # CHANGE THIS
    
    img1 = x_train[i]    
    ax[i, 0].imshow(img1, cmap=plt.cm.binary)
    ax[i, 0].axis("off")
    
    img2 = x_train_flipped[i]    
    ax[i, 1].imshow(img2, cmap=plt.cm.binary)
    ax[i, 1].axis("off")
        
plt.show()
# Out:
# (54000, 28, 28)

# %%
def cropall(images):
    images = images.reshape((*images.shape,1))
    images = tf.image.central_crop(images, 0.8)
    images = tf.image.resize(images, (28,28))
    images = images.numpy().reshape(images.shape[:3])

    return images

cropped_test = cropall(x_train[0])
plt.imshow(x_train[0])
plt.show()
plt.imshow(cropped_test)
plt.show()

print("\n"+"="*50+"\n")
    
x_train_cropped = cropall(x_train)
print(x_train_cropped.shape)

WIDTH = 10                # CHANGE THIS
HEIGHT = 20               # CHANGE THIS

fig, ax = plt.subplots(10, 2, figsize=(WIDTH, HEIGHT))

for i in range(10):        # CHANGE THIS
    
    img1 = x_train[i]    
    ax[i, 0].imshow(img1, cmap=plt.cm.binary)
    ax[i, 0].axis("off")
    
    img2 = x_train_cropped[i]    
    ax[i, 1].imshow(img2, cmap=plt.cm.binary)
    ax[i, 1].axis("off")
        
plt.show()
# Out:
# ==================================================
#
# (54000, 28, 28)

# %% [markdown]
# # Simple Baseline Model

# %%
baseline_model = Sequential([
    layers.Conv2D(32, (2,2), activation="relu", input_shape=(28, 28, 1)),
    layers.Flatten(), # 2d to 1d
    layers.Dense(16, activation="relu"),
    layers.Dense(10)
])

baseline_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

print(baseline_model.summary())
checkpoint = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/baseline.hdf5',verbose=True)
getAcc = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/baseline_Acc.hdf5',verbose=True,save_best_only=True,monitor='val_accuracy')
getLoss = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/baseline_Loss.hdf5',verbose=True,save_best_only=True,monitor='val_loss')
baseline_model_history = baseline_model.fit(x_train, y_train, 
                                                epochs=10, 
                                                validation_data=(x_val, y_val),
                                                callbacks=[checkpoint,getAcc,getLoss, 
                                                EarlyStopping(monitor='val_accuracy', mode='max',patience=5)])

baseline_model_history
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 27, 27, 32)        160
#
#  flatten (Flatten)           (None, 23328)             0
#
#  dense (Dense)               (None, 16)                373264
#
#  dense_1 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 373,594
# Trainable params: 373,594
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 1688/1688 [==============================] - ETA: 0s - loss: 0.5319 - accuracy: 0.8143
# Epoch 1: saving model to tmp/checkpoint\baseline.hdf5
#
# Epoch 1: val_accuracy improved from -inf to 0.86600, saving model to tmp/checkpoint\baseline_Acc.hdf5
#
# Epoch 1: val_loss improved from inf to 0.36835, saving model to tmp/checkpoint\baseline_Loss.hdf5
# 1688/1688 [==============================] - 33s 14ms/step - loss: 0.5319 - accuracy: 0.8143 - val_loss: 0.3683 - val_accuracy: 0.8660
# Epoch 2/10
# 1688/1688 [==============================] - ETA: 0s - loss: 0.3171 - accuracy: 0.8857
# Epoch 2: saving model to tmp/checkpoint\baseline.hdf5
#
# Epoch 2: val_accuracy improved from 0.86600 to 0.88917, saving model to tmp/checkpoint\baseline_Acc.hdf5
#
# Epoch 2: val_loss improved from 0.36835 to 0.31027, saving model to tmp/checkpoint\baseline_Loss.hdf5
# 1688/1688 [==============================] - 22s 13ms/step - loss: 0.3171 - accuracy: 0.8857 - val_loss: 0.3103 - val_accuracy: 0.8892
# Epoch 3/10
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.2723 - accuracy: 0.9024
# Epoch 3: saving model to tmp/checkpoint\baseline.hdf5
#
# Epoch 3: val_accuracy improved from 0.88917 to 0.90067, saving model to tmp/checkpoint\baseline_Acc.hdf5
#
# Epoch 3: val_loss improved from 0.31027 to 0.28297, saving model to tmp/checkpoint\baseline_Loss.hdf5
# 1688/1688 [==============================] - 21s 12ms/step - loss: 0.2723 - accuracy: 0.9024 - val_loss: 0.2830 - val_accuracy: 0.9007
# Epoch 4/10
# 1683/1688 [============================>.] - ETA: 0s - loss: 0.2411 - accuracy: 0.9131
# Epoch 4: saving model to tmp/checkpoint\baseline.hdf5
#
# Epoch 4: val_accuracy did not improve from 0.90067
#
# Epoch 4: val_loss did not improve from 0.28297
# 1688/1688 [==============================] - 18s 11ms/step - loss: 0.2410 - accuracy: 0.9132 - val_loss: 0.2892 - val_accuracy: 0.8992
# Epoch 5/10
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.2178 - accuracy: 0.9217
# Epoch 5: saving model to tmp/checkpoint\baseline.hdf5
#
# Epoch 5: val_accuracy improved from 0.90067 to 0.90267, saving model to tmp/checkpoint\baseline_Acc.hdf5
#
# Epoch 5: val_loss improved from 0.28297 to 0.28262, saving model to tmp/checkpoint\baseline_Loss.hdf5
# 1688/1688 [==============================] - 19s 11ms/step - loss: 0.2178 - accuracy: 0.9216 - val_loss: 0.2826 - val_accuracy: 0.9027
# Epoch 6/10
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9278
# Epoch 6: saving model to tmp/checkpoint\baseline.hdf5
#
# Epoch 6: val_accuracy did not improve from 0.90267
#
# Epoch 6: val_loss did not improve from 0.28262
# 1688/1688 [==============================] - 17s 10ms/step - loss: 0.1986 - accuracy: 0.9278 - val_loss: 0.2997 - val_accuracy: 0.8983
# Epoch 7/10
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.1801 - accuracy: 0.9351
# Epoch 7: saving model to tmp/checkpoint\baseline.hdf5
#
# Epoch 7: val_accuracy improved from 0.90267 to 0.90467, saving model to tmp/checkpoint\baseline_Acc.hdf5
#
# Epoch 7: val_loss did not improve from 0.28262
# 1688/1688 [==============================] - 16s 9ms/step - loss: 0.1802 - accuracy: 0.9350 - val_loss: 0.2964 - val_accuracy: 0.9047
# Epoch 8/10
# 1683/1688 [============================>.] - ETA: 0s - loss: 0.1638 - accuracy: 0.9416
# Epoch 8: saving model to tmp/checkpoint\baseline.hdf5
#
# Epoch 8: val_accuracy did not improve from 0.90467
#
# Epoch 8: val_loss did not improve from 0.28262
# 1688/1688 [==============================] - 16s 9ms/step - loss: 0.1638 - accuracy: 0.9415 - val_loss: 0.2969 - val_accuracy: 0.9037
# Epoch 9/10
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.1460 - accuracy: 0.9474
# Epoch 9: saving model to tmp/checkpoint\baseline.hdf5
#
# Epoch 9: val_accuracy did not improve from 0.90467
#
# Epoch 9: val_loss did not improve from 0.28262
# 1688/1688 [==============================] - 16s 9ms/step - loss: 0.1462 - accuracy: 0.9473 - val_loss: 0.3260 - val_accuracy: 0.9003
# Epoch 10/10
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.1345 - accuracy: 0.9520
# Epoch 10: saving model to tmp/checkpoint\baseline.hdf5
#
# Epoch 10: val_accuracy did not improve from 0.90467
#
# Epoch 10: val_loss did not improve from 0.28262
# 1688/1688 [==============================] - 16s 9ms/step - loss: 0.1345 - accuracy: 0.9520 - val_loss: 0.3303 - val_accuracy: 0.8983

# %% [markdown]
# ## Baseline Model Evaluation

# %%
# evaluating baseline coarse model
print(baseline_model.evaluate(x_test, y_test))
baseline_model.load_weights('tmp/checkpoint/baseline_Acc.hdf5')
scoreAcc = baseline_model.evaluate(x_test, y_test)
baseline_model.load_weights('tmp/checkpoint/baseline_Loss.hdf5')
scoreLoss = baseline_model.evaluate(x_test, y_test)
print('Best Acc Test Loss:', scoreAcc[0])
print('Best Acc Test Accuracy:', round(scoreAcc[1],4)*100,'%')
print('Best Loss Test Loss:', scoreLoss[0])
print('Best Loss Test Accuracy:', round(scoreLoss[1],4)*100,'%')
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3424 - accuracy: 0.8939
# [0.3423987925052643, 0.8938999772071838]
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3109 - accuracy: 0.8946
# 313/313 [==============================] - 3s 8ms/step - loss: 0.2967 - accuracy: 0.8954
# Best Acc Test Loss: 0.3108822703361511
# Best Acc Test Accuracy: 89.46 %
# Best Loss Test Loss: 0.2966615855693817
# Best Loss Test Accuracy: 89.53999999999999 %

# %% [markdown]
# ## Baseline Training and validation Accuracy

# %%
max_val_acc_epoch = np.argmax(list(baseline_model_history.history['val_accuracy']))+1
max_val_loss_epoch = np.argmin(list(baseline_model_history.history['val_loss']))+1
epochs = range(1, len(baseline_model_history.history['accuracy']) + 1)
plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,baseline_model_history.history['accuracy'], label='Train')
plt.plot(epochs,baseline_model_history.history['val_accuracy'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,baseline_model_history.history['loss'], label='Train')
plt.plot(epochs,baseline_model_history.history['val_loss'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import visualkeras
from PIL import ImageFont
visualkeras.layered_view(baseline_model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=532x180>

# %%
baseline_model.save_weights("./tmp/fashion-baseline-model.h5")

# %% [markdown]
# <h3><b>3. Modelling & Evaluation</h3></b>

# %% [markdown]
# <h3>Metrics Used</h3>
#
# * Top 1 accuracy
# * Top 3 accuracy
# * Loss

# %% [markdown]
# # Own model

# %%
own_model = Sequential([
    layers.Conv2D(32, (3,3), activation="relu", input_shape=(28, 28, 1)),  
    layers.Conv2D(64, (3,3), activation="relu"),  
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, (3,3), activation="relu"),
    layers.Conv2D(64, (3,3), activation="relu"),  
    layers.BatchNormalization(),  
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.1),
    layers.Flatten(), # 2d to 1d
    layers.Dense(64, activation="relu"),
    layers.Dense(10)
])

own_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
print(own_model.summary())
#early stopping to monitor the validation loss and avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, restore_best_weights=True)

#reducing learning rate on plateau
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience= 5, factor= 0.5, min_lr= 1e-6, verbose=1)
checkpoint = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/ownModel.hdf5',verbose=True)
getAcc = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/ownModelAcc.hdf5',verbose=True,save_best_only=True,monitor='val_accuracy')
getLoss = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/ownModelLoss.hdf5',verbose=True,save_best_only=True,monitor='val_loss')
own_model_history = own_model.fit(x_train, y_train, 
                                                epochs=20, 
                                                validation_data=(x_val, y_val), 
                                                callbacks=[checkpoint,getAcc,getLoss, 
                                                early_stop, rlrop])

own_model_history
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 64)        18496
#
#  batch_normalization (BatchN  (None, 24, 24, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 64)        36928
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          36928
#
#  batch_normalization_1 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 64)          0
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 64)                65600
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 159,434
# Trainable params: 159,178
# Non-trainable params: 256
# _________________________________________________________________
# None
# Epoch 1/20
# 1688/1688 [==============================] - ETA: 0s - loss: 0.4175 - accuracy: 0.8489
# Epoch 1: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 1: val_accuracy improved from -inf to 0.87617, saving model to tmp/checkpoint\ownModelAcc.hdf5
#
# Epoch 1: val_loss improved from inf to 0.32848, saving model to tmp/checkpoint\ownModelLoss.hdf5
# 1688/1688 [==============================] - 29s 16ms/step - loss: 0.4175 - accuracy: 0.8489 - val_loss: 0.3285 - val_accuracy: 0.8762 - lr: 0.0010
# Epoch 2/20
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.2778 - accuracy: 0.8987
# Epoch 2: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 2: val_accuracy improved from 0.87617 to 0.89717, saving model to tmp/checkpoint\ownModelAcc.hdf5
#
# Epoch 2: val_loss improved from 0.32848 to 0.27777, saving model to tmp/checkpoint\ownModelLoss.hdf5
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.2778 - accuracy: 0.8986 - val_loss: 0.2778 - val_accuracy: 0.8972 - lr: 0.0010
# Epoch 3/20
# 1688/1688 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.9134
# Epoch 3: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 3: val_accuracy improved from 0.89717 to 0.90883, saving model to tmp/checkpoint\ownModelAcc.hdf5
#
# Epoch 3: val_loss improved from 0.27777 to 0.24490, saving model to tmp/checkpoint\ownModelLoss.hdf5
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.2394 - accuracy: 0.9134 - val_loss: 0.2449 - val_accuracy: 0.9088 - lr: 0.0010
# Epoch 4/20
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.2149 - accuracy: 0.9209
# Epoch 4: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 4: val_accuracy improved from 0.90883 to 0.91417, saving model to tmp/checkpoint\ownModelAcc.hdf5
#
# Epoch 4: val_loss improved from 0.24490 to 0.23022, saving model to tmp/checkpoint\ownModelLoss.hdf5
# 1688/1688 [==============================] - 26s 15ms/step - loss: 0.2151 - accuracy: 0.9208 - val_loss: 0.2302 - val_accuracy: 0.9142 - lr: 0.0010
# Epoch 5/20
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1910 - accuracy: 0.9293
# Epoch 5: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 5: val_accuracy improved from 0.91417 to 0.91917, saving model to tmp/checkpoint\ownModelAcc.hdf5
#
# Epoch 5: val_loss improved from 0.23022 to 0.22663, saving model to tmp/checkpoint\ownModelLoss.hdf5
# 1688/1688 [==============================] - 26s 15ms/step - loss: 0.1910 - accuracy: 0.9293 - val_loss: 0.2266 - val_accuracy: 0.9192 - lr: 0.0010
# Epoch 6/20
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1707 - accuracy: 0.9369
# Epoch 6: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 6: val_accuracy did not improve from 0.91917
#
# Epoch 6: val_loss did not improve from 0.22663
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.1707 - accuracy: 0.9369 - val_loss: 0.2653 - val_accuracy: 0.9100 - lr: 0.0010
# Epoch 7/20
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1548 - accuracy: 0.9429
# Epoch 7: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 7: val_accuracy did not improve from 0.91917
#
# Epoch 7: val_loss did not improve from 0.22663
# 1688/1688 [==============================] - 30s 18ms/step - loss: 0.1548 - accuracy: 0.9429 - val_loss: 0.2363 - val_accuracy: 0.9153 - lr: 0.0010
# Epoch 8/20
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.1375 - accuracy: 0.9489
# Epoch 8: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 8: val_accuracy improved from 0.91917 to 0.92200, saving model to tmp/checkpoint\ownModelAcc.hdf5
#
# Epoch 8: val_loss improved from 0.22663 to 0.22239, saving model to tmp/checkpoint\ownModelLoss.hdf5
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.1374 - accuracy: 0.9490 - val_loss: 0.2224 - val_accuracy: 0.9220 - lr: 0.0010
# Epoch 9/20
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 0.9536
# Epoch 9: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 9: val_accuracy did not improve from 0.92200
#
# Epoch 9: val_loss did not improve from 0.22239
# 1688/1688 [==============================] - 26s 16ms/step - loss: 0.1259 - accuracy: 0.9536 - val_loss: 0.2368 - val_accuracy: 0.9203 - lr: 0.0010
# Epoch 10/20
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9578
# Epoch 10: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 10: val_accuracy improved from 0.92200 to 0.92433, saving model to tmp/checkpoint\ownModelAcc.hdf5
#
# Epoch 10: val_loss did not improve from 0.22239
# 1688/1688 [==============================] - 26s 15ms/step - loss: 0.1119 - accuracy: 0.9578 - val_loss: 0.2327 - val_accuracy: 0.9243 - lr: 0.0010
# Epoch 11/20
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9609
# Epoch 11: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 11: val_accuracy improved from 0.92433 to 0.92900, saving model to tmp/checkpoint\ownModelAcc.hdf5
#
# Epoch 11: val_loss did not improve from 0.22239
# 1688/1688 [==============================] - 26s 16ms/step - loss: 0.1044 - accuracy: 0.9609 - val_loss: 0.2375 - val_accuracy: 0.9290 - lr: 0.0010
# Epoch 12/20
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.0961 - accuracy: 0.9646
# Epoch 12: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 12: val_accuracy did not improve from 0.92900
#
# Epoch 12: val_loss did not improve from 0.22239
# 1688/1688 [==============================] - 26s 16ms/step - loss: 0.0962 - accuracy: 0.9646 - val_loss: 0.2507 - val_accuracy: 0.9267 - lr: 0.0010
# Epoch 13/20
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.0865 - accuracy: 0.9682
# Epoch 13: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 13: val_accuracy did not improve from 0.92900
#
# Epoch 13: val_loss did not improve from 0.22239
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1688/1688 [==============================] - 26s 15ms/step - loss: 0.0865 - accuracy: 0.9682 - val_loss: 0.2438 - val_accuracy: 0.9218 - lr: 0.0010
# Epoch 14/20
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.0532 - accuracy: 0.9805
# Epoch 14: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 14: val_accuracy improved from 0.92900 to 0.93017, saving model to tmp/checkpoint\ownModelAcc.hdf5
#
# Epoch 14: val_loss did not improve from 0.22239
# 1688/1688 [==============================] - 26s 16ms/step - loss: 0.0532 - accuracy: 0.9805 - val_loss: 0.2519 - val_accuracy: 0.9302 - lr: 5.0000e-04
# Epoch 15/20
# 1688/1688 [==============================] - ETA: 0s - loss: 0.0438 - accuracy: 0.9840
# Epoch 15: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 15: val_accuracy improved from 0.93017 to 0.93167, saving model to tmp/checkpoint\ownModelAcc.hdf5
#
# Epoch 15: val_loss did not improve from 0.22239
# 1688/1688 [==============================] - 27s 16ms/step - loss: 0.0438 - accuracy: 0.9840 - val_loss: 0.2638 - val_accuracy: 0.9317 - lr: 5.0000e-04
# Epoch 16/20
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.0358 - accuracy: 0.9871
# Epoch 16: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 16: val_accuracy did not improve from 0.93167
#
# Epoch 16: val_loss did not improve from 0.22239
# 1688/1688 [==============================] - 26s 15ms/step - loss: 0.0358 - accuracy: 0.9871 - val_loss: 0.2824 - val_accuracy: 0.9273 - lr: 5.0000e-04
# Epoch 17/20
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.0332 - accuracy: 0.9881
# Epoch 17: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 17: val_accuracy did not improve from 0.93167
#
# Epoch 17: val_loss did not improve from 0.22239
# 1688/1688 [==============================] - 26s 15ms/step - loss: 0.0333 - accuracy: 0.9881 - val_loss: 0.3106 - val_accuracy: 0.9298 - lr: 5.0000e-04
# Epoch 18/20
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9886
# Epoch 18: saving model to tmp/checkpoint\ownModel.hdf5
#
# Epoch 18: val_accuracy did not improve from 0.93167
#
# Epoch 18: val_loss did not improve from 0.22239
# Restoring model weights from the end of the best epoch: 8.
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1688/1688 [==============================] - 26s 16ms/step - loss: 0.0314 - accuracy: 0.9886 - val_loss: 0.3117 - val_accuracy: 0.9270 - lr: 5.0000e-04
# Epoch 18: early stopping

# %% [markdown]
# ## Own Model Evaluation

# %%
# evaluating baseline coarse model
print(own_model.evaluate(x_test, y_test))
own_model.load_weights('tmp/checkpoint/ownModelAcc.hdf5')
scoreAcc = own_model.evaluate(x_test, y_test)
own_model.load_weights('tmp/checkpoint/ownModelLoss.hdf5')
scoreLoss = own_model.evaluate(x_test, y_test)
print('Best Acc Test Loss:', scoreAcc[0])
print('Best Acc Test Accuracy:', round(scoreAcc[1],4)*100,'%')
print('Best Loss Test Loss:', scoreLoss[0])
print('Best Loss Test Accuracy:', round(scoreLoss[1],4)*100,'%')
# Out:
# 313/313 [==============================] - 3s 10ms/step - loss: 0.2525 - accuracy: 0.9155
# [0.25252196192741394, 0.9154999852180481]
# 313/313 [==============================] - 3s 8ms/step - loss: 0.3153 - accuracy: 0.9245
# 313/313 [==============================] - 3s 9ms/step - loss: 0.2525 - accuracy: 0.9155
# Best Acc Test Loss: 0.31533002853393555
# Best Acc Test Accuracy: 92.45 %
# Best Loss Test Loss: 0.25252196192741394
# Best Loss Test Accuracy: 91.55 %

# %% [markdown]
# ## Own model Training and validation Accuracy & Loss

# %%
max_val_acc_epoch = np.argmax(list(own_model_history.history['val_accuracy']))+1
max_val_loss_epoch = np.argmin(list(own_model_history.history['val_loss']))+1
epochs = range(1, len(own_model_history.history['accuracy']) + 1)
plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,own_model_history.history['accuracy'], label='Train')
plt.plot(epochs,own_model_history.history['val_accuracy'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,own_model_history.history['loss'], label='Train')
plt.plot(epochs,own_model_history.history['val_loss'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import visualkeras
from PIL import ImageFont
visualkeras.layered_view(own_model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=474x201>

# %%
own_model.save_weights("./tmp/fashion-own-model.h5")

# %% [markdown]
# <h3><b>4. Model Improvement with augmented data</h3></b>

# %%
x_train_augmented = list(x_train) + list(x_train_flipped) + list(x_train_cropped)
x_train_augmented = np.array(x_train_augmented)

y_train_augmented = np.array(list(y_train) * 3)

x_train_augmented.shape, y_train_augmented.shape
# Out:
# ((162000, 28, 28), (162000,))

# %%
baseline_augmented_model = Sequential([
    layers.Conv2D(64, (4,4), activation="relu", input_shape=(28, 28, 1)),
    #layers.MaxPooling2D((2, 2)),
    layers.Flatten(), # 2d to 1d
    layers.Dense(128, activation="relu"),
    layers.Dense(10)
])

#copy pasted from documentation
baseline_augmented_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

print(baseline_augmented_model.summary())

checkpoint = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/baseline_augmented.hdf5',verbose=True)
getAcc = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/baseline_augmentedAcc.hdf5',verbose=True,save_best_only=True,monitor='val_accuracy')
getLoss = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/baseline_augmentedLoss.hdf5',verbose=True,save_best_only=True,monitor='val_loss')
baseline_augmented_history = baseline_augmented_model.fit(x_train_augmented, y_train_augmented, 
                                                epochs=20, 
                                                validation_data=(x_val, y_val), 
                                                callbacks=[checkpoint,getAcc,getLoss, 
                                                EarlyStopping(monitor='val_accuracy', mode='max',patience=5)])


baseline_augmented_history
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 25, 25, 64)        1088
#
#  flatten_4 (Flatten)         (None, 40000)             0
#
#  dense_8 (Dense)             (None, 128)               5120128
#
#  dense_9 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 5,122,506
# Trainable params: 5,122,506
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 5060/5063 [============================>.] - ETA: 0s - loss: 0.3637 - accuracy: 0.8669
# Epoch 1: saving model to tmp/checkpoint\baseline_augmented.hdf5
#
# Epoch 1: val_accuracy improved from -inf to 0.89217, saving model to tmp/checkpoint\baseline_augmentedAcc.hdf5
#
# Epoch 1: val_loss improved from inf to 0.28198, saving model to tmp/checkpoint\baseline_augmentedLoss.hdf5
# 5063/5063 [==============================] - 38s 7ms/step - loss: 0.3636 - accuracy: 0.8669 - val_loss: 0.2820 - val_accuracy: 0.8922
# Epoch 2/20
# 5056/5063 [============================>.] - ETA: 0s - loss: 0.2421 - accuracy: 0.9099
# Epoch 2: saving model to tmp/checkpoint\baseline_augmented.hdf5
#
# Epoch 2: val_accuracy improved from 0.89217 to 0.90317, saving model to tmp/checkpoint\baseline_augmentedAcc.hdf5
#
# Epoch 2: val_loss improved from 0.28198 to 0.27040, saving model to tmp/checkpoint\baseline_augmentedLoss.hdf5
# 5063/5063 [==============================] - 36s 7ms/step - loss: 0.2421 - accuracy: 0.9100 - val_loss: 0.2704 - val_accuracy: 0.9032
# Epoch 3/20
# 5063/5063 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9297
# Epoch 3: saving model to tmp/checkpoint\baseline_augmented.hdf5
#
# Epoch 3: val_accuracy improved from 0.90317 to 0.90933, saving model to tmp/checkpoint\baseline_augmentedAcc.hdf5
#
# Epoch 3: val_loss did not improve from 0.27040
# 5063/5063 [==============================] - 35s 7ms/step - loss: 0.1876 - accuracy: 0.9297 - val_loss: 0.2801 - val_accuracy: 0.9093
# Epoch 4/20
# 5063/5063 [==============================] - ETA: 0s - loss: 0.1493 - accuracy: 0.9438
# Epoch 4: saving model to tmp/checkpoint\baseline_augmented.hdf5
#
# Epoch 4: val_accuracy did not improve from 0.90933
#
# Epoch 4: val_loss did not improve from 0.27040
# 5063/5063 [==============================] - 35s 7ms/step - loss: 0.1493 - accuracy: 0.9438 - val_loss: 0.3254 - val_accuracy: 0.9068
# Epoch 5/20
# 5063/5063 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9547
# Epoch 5: saving model to tmp/checkpoint\baseline_augmented.hdf5
#
# Epoch 5: val_accuracy did not improve from 0.90933
#
# Epoch 5: val_loss did not improve from 0.27040
# 5063/5063 [==============================] - 35s 7ms/step - loss: 0.1208 - accuracy: 0.9547 - val_loss: 0.3613 - val_accuracy: 0.9073
# Epoch 6/20
# 5056/5063 [============================>.] - ETA: 0s - loss: 0.0972 - accuracy: 0.9639
# Epoch 6: saving model to tmp/checkpoint\baseline_augmented.hdf5
#
# Epoch 6: val_accuracy improved from 0.90933 to 0.91250, saving model to tmp/checkpoint\baseline_augmentedAcc.hdf5
#
# Epoch 6: val_loss did not improve from 0.27040
# 5063/5063 [==============================] - 35s 7ms/step - loss: 0.0972 - accuracy: 0.9639 - val_loss: 0.4235 - val_accuracy: 0.9125
# Epoch 7/20
# 5063/5063 [==============================] - ETA: 0s - loss: 0.0810 - accuracy: 0.9700
# Epoch 7: saving model to tmp/checkpoint\baseline_augmented.hdf5
#
# Epoch 7: val_accuracy did not improve from 0.91250
#
# Epoch 7: val_loss did not improve from 0.27040
# 5063/5063 [==============================] - 33s 7ms/step - loss: 0.0810 - accuracy: 0.9700 - val_loss: 0.4406 - val_accuracy: 0.9070
# Epoch 8/20
# 5062/5063 [============================>.] - ETA: 0s - loss: 0.0697 - accuracy: 0.9745
# Epoch 8: saving model to tmp/checkpoint\baseline_augmented.hdf5
#
# Epoch 8: val_accuracy did not improve from 0.91250
#
# Epoch 8: val_loss did not improve from 0.27040
# 5063/5063 [==============================] - 33s 7ms/step - loss: 0.0697 - accuracy: 0.9745 - val_loss: 0.5101 - val_accuracy: 0.9083
# Epoch 9/20
# 5057/5063 [============================>.] - ETA: 0s - loss: 0.0575 - accuracy: 0.9790
# Epoch 9: saving model to tmp/checkpoint\baseline_augmented.hdf5
#
# Epoch 9: val_accuracy did not improve from 0.91250
#
# Epoch 9: val_loss did not improve from 0.27040
# 5063/5063 [==============================] - 33s 7ms/step - loss: 0.0575 - accuracy: 0.9790 - val_loss: 0.5539 - val_accuracy: 0.9037
# Epoch 10/20
# 5061/5063 [============================>.] - ETA: 0s - loss: 0.0512 - accuracy: 0.9813
# Epoch 10: saving model to tmp/checkpoint\baseline_augmented.hdf5
#
# Epoch 10: val_accuracy did not improve from 0.91250
#
# Epoch 10: val_loss did not improve from 0.27040
# 5063/5063 [==============================] - 34s 7ms/step - loss: 0.0512 - accuracy: 0.9813 - val_loss: 0.6563 - val_accuracy: 0.9032
# Epoch 11/20
# 5058/5063 [============================>.] - ETA: 0s - loss: 0.0451 - accuracy: 0.9835
# Epoch 11: saving model to tmp/checkpoint\baseline_augmented.hdf5
#
# Epoch 11: val_accuracy did not improve from 0.91250
#
# Epoch 11: val_loss did not improve from 0.27040
# 5063/5063 [==============================] - 34s 7ms/step - loss: 0.0451 - accuracy: 0.9835 - val_loss: 0.6887 - val_accuracy: 0.9048

# %% [markdown]
# ## Baseline Augmented Model Evaluation

# %%
# evaluating baseline coarse model
print(baseline_augmented_model.evaluate(x_test, y_test))
baseline_augmented_model.load_weights('tmp/checkpoint/baseline_augmentedAcc.hdf5')
scoreAcc = baseline_augmented_model.evaluate(x_test, y_test)
baseline_augmented_model.load_weights('tmp/checkpoint/baseline_augmentedLoss.hdf5')
scoreLoss = baseline_augmented_model.evaluate(x_test, y_test)
print('Best Acc Test Loss:', scoreAcc[0])
print('Best Acc Test Accuracy:', round(scoreAcc[1],4)*100,'%')
print('Best Loss Test Loss:', scoreLoss[0])
print('Best Loss Test Accuracy:', round(scoreLoss[1],4)*100,'%')
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.6979 - accuracy: 0.9041
# [0.6978669166564941, 0.9041000008583069]
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4296 - accuracy: 0.9074
# 313/313 [==============================] - 1s 5ms/step - loss: 0.2796 - accuracy: 0.8979
# Best Acc Test Loss: 0.42958661913871765
# Best Acc Test Accuracy: 90.74 %
# Best Loss Test Loss: 0.2795814573764801
# Best Loss Test Accuracy: 89.79 %

# %%
import visualkeras
from PIL import ImageFont
visualkeras.layered_view(baseline_augmented_model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=530x170>

# %%
max_val_acc_epoch = np.argmax(list(baseline_augmented_history.history['val_accuracy']))+1
max_val_loss_epoch = np.argmin(list(baseline_augmented_history.history['val_loss']))+1
epochs = range(1, len(baseline_augmented_history.history['accuracy']) + 1)
plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,baseline_augmented_history.history['accuracy'], label='Train')
plt.plot(epochs,baseline_augmented_history.history['val_accuracy'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,baseline_augmented_history.history['loss'], label='Train')
plt.plot(epochs,baseline_augmented_history.history['val_loss'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
baseline_augmented_model.save_weights("./tmp/fashion_baseline_augmented_model.h5")

# %% [markdown]
# ## Own Augmented Model

# %%
own_augmented_model = Sequential([
    layers.Conv2D(64, (3,3), activation="relu", input_shape=(28, 28, 1)),  
    layers.Conv2D(64, (3,3), activation="relu"),  
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3,3), activation="relu"),
    layers.Conv2D(128, (3,3), activation="relu"),  
    layers.BatchNormalization(),  
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.1),
    # layers.Conv2D(256, (3,3), activation="relu"),
    # layers.Conv2D(256, (3,3), activation="relu"),  
    # layers.BatchNormalization(),  
    # layers.MaxPooling2D((2, 2)),
    # layers.Dropout(0.1),
    layers.Flatten(), # 2d to 1d
    layers.Dense(64, activation="relu"),
    layers.Dense(10)
])

own_augmented_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


#early stopping to monitor the validation loss and avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, restore_best_weights=True)

#reducing learning rate on plateau
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience= 5, factor= 0.5, min_lr= 1e-6, verbose=1)

print(own_augmented_model.summary())
checkpoint = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/own_augmented.hdf5',verbose=True)
getAcc = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/own_augmentedAcc.hdf5',verbose=True,save_best_only=True,monitor='val_accuracy')
getLoss = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/own_augmentedLoss.hdf5',verbose=True,save_best_only=True,monitor='val_loss')
history_augmented = own_augmented_model.fit(x_train_augmented, y_train_augmented, 
                                                epochs=30, 
                                                validation_data=(x_val, y_val), 
                                                callbacks=[checkpoint,getAcc,getLoss, 
                                                rlrop, early_stop])

history_augmented
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 26, 26, 64)        640
#
#  conv2d_12 (Conv2D)          (None, 24, 24, 64)        36928
#
#  batch_normalization_4 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 10, 10, 128)       73856
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_5 (Flatten)         (None, 2048)              0
#
#  dense_10 (Dense)            (None, 64)                131136
#
#  dense_11 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 391,562
# Trainable params: 391,178
# Non-trainable params: 384
# _________________________________________________________________
# None
# Epoch 1/30
# 5061/5063 [============================>.] - ETA: 0s - loss: 0.3630 - accuracy: 0.8675
# Epoch 1: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 1: val_accuracy improved from -inf to 0.90683, saving model to tmp/checkpoint\own_augmentedAcc.hdf5
#
# Epoch 1: val_loss improved from inf to 0.25630, saving model to tmp/checkpoint\own_augmentedLoss.hdf5
# 5063/5063 [==============================] - 45s 9ms/step - loss: 0.3630 - accuracy: 0.8675 - val_loss: 0.2563 - val_accuracy: 0.9068 - lr: 0.0010
# Epoch 2/30
# 5059/5063 [============================>.] - ETA: 0s - loss: 0.2450 - accuracy: 0.9100
# Epoch 2: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 2: val_accuracy improved from 0.90683 to 0.91683, saving model to tmp/checkpoint\own_augmentedAcc.hdf5
#
# Epoch 2: val_loss improved from 0.25630 to 0.23264, saving model to tmp/checkpoint\own_augmentedLoss.hdf5
# 5063/5063 [==============================] - 44s 9ms/step - loss: 0.2449 - accuracy: 0.9100 - val_loss: 0.2326 - val_accuracy: 0.9168 - lr: 0.0010
# Epoch 3/30
# 5058/5063 [============================>.] - ETA: 0s - loss: 0.2073 - accuracy: 0.9237
# Epoch 3: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 3: val_accuracy improved from 0.91683 to 0.92467, saving model to tmp/checkpoint\own_augmentedAcc.hdf5
#
# Epoch 3: val_loss improved from 0.23264 to 0.22346, saving model to tmp/checkpoint\own_augmentedLoss.hdf5
# 5063/5063 [==============================] - 44s 9ms/step - loss: 0.2074 - accuracy: 0.9237 - val_loss: 0.2235 - val_accuracy: 0.9247 - lr: 0.0010
# Epoch 4/30
# 5063/5063 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9339
# Epoch 4: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 4: val_accuracy improved from 0.92467 to 0.92767, saving model to tmp/checkpoint\own_augmentedAcc.hdf5
#
# Epoch 4: val_loss improved from 0.22346 to 0.21710, saving model to tmp/checkpoint\own_augmentedLoss.hdf5
# 5063/5063 [==============================] - 45s 9ms/step - loss: 0.1783 - accuracy: 0.9339 - val_loss: 0.2171 - val_accuracy: 0.9277 - lr: 0.0010
# Epoch 5/30
# 5062/5063 [============================>.] - ETA: 0s - loss: 0.1558 - accuracy: 0.9417
# Epoch 5: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 5: val_accuracy did not improve from 0.92767
#
# Epoch 5: val_loss did not improve from 0.21710
# 5063/5063 [==============================] - 45s 9ms/step - loss: 0.1557 - accuracy: 0.9417 - val_loss: 0.2398 - val_accuracy: 0.9263 - lr: 0.0010
# Epoch 6/30
# 5059/5063 [============================>.] - ETA: 0s - loss: 0.1371 - accuracy: 0.9489
# Epoch 6: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 6: val_accuracy improved from 0.92767 to 0.93000, saving model to tmp/checkpoint\own_augmentedAcc.hdf5
#
# Epoch 6: val_loss improved from 0.21710 to 0.21484, saving model to tmp/checkpoint\own_augmentedLoss.hdf5
# 5063/5063 [==============================] - 47s 9ms/step - loss: 0.1372 - accuracy: 0.9489 - val_loss: 0.2148 - val_accuracy: 0.9300 - lr: 0.0010
# Epoch 7/30
# 5061/5063 [============================>.] - ETA: 0s - loss: 0.1207 - accuracy: 0.9554
# Epoch 7: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 7: val_accuracy improved from 0.93000 to 0.93050, saving model to tmp/checkpoint\own_augmentedAcc.hdf5
#
# Epoch 7: val_loss did not improve from 0.21484
# 5063/5063 [==============================] - 46s 9ms/step - loss: 0.1207 - accuracy: 0.9554 - val_loss: 0.2244 - val_accuracy: 0.9305 - lr: 0.0010
# Epoch 8/30
# 5060/5063 [============================>.] - ETA: 0s - loss: 0.1061 - accuracy: 0.9606
# Epoch 8: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 8: val_accuracy improved from 0.93050 to 0.93167, saving model to tmp/checkpoint\own_augmentedAcc.hdf5
#
# Epoch 8: val_loss did not improve from 0.21484
# 5063/5063 [==============================] - 48s 10ms/step - loss: 0.1061 - accuracy: 0.9606 - val_loss: 0.2274 - val_accuracy: 0.9317 - lr: 0.0010
# Epoch 9/30
# 5058/5063 [============================>.] - ETA: 0s - loss: 0.0974 - accuracy: 0.9635
# Epoch 9: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 9: val_accuracy did not improve from 0.93167
#
# Epoch 9: val_loss did not improve from 0.21484
# 5063/5063 [==============================] - 53s 10ms/step - loss: 0.0974 - accuracy: 0.9636 - val_loss: 0.2471 - val_accuracy: 0.9312 - lr: 0.0010
# Epoch 10/30
# 5060/5063 [============================>.] - ETA: 0s - loss: 0.0853 - accuracy: 0.9683
# Epoch 10: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 10: val_accuracy did not improve from 0.93167
#
# Epoch 10: val_loss did not improve from 0.21484
# 5063/5063 [==============================] - 53s 11ms/step - loss: 0.0854 - accuracy: 0.9683 - val_loss: 0.2651 - val_accuracy: 0.9260 - lr: 0.0010
# Epoch 11/30
# 5062/5063 [============================>.] - ETA: 0s - loss: 0.0785 - accuracy: 0.9711
# Epoch 11: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 11: val_accuracy improved from 0.93167 to 0.93567, saving model to tmp/checkpoint\own_augmentedAcc.hdf5
#
# Epoch 11: val_loss did not improve from 0.21484
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5063/5063 [==============================] - 53s 10ms/step - loss: 0.0785 - accuracy: 0.9711 - val_loss: 0.2430 - val_accuracy: 0.9357 - lr: 0.0010
# Epoch 12/30
# 5059/5063 [============================>.] - ETA: 0s - loss: 0.0472 - accuracy: 0.9827
# Epoch 12: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 12: val_accuracy improved from 0.93567 to 0.93817, saving model to tmp/checkpoint\own_augmentedAcc.hdf5
#
# Epoch 12: val_loss did not improve from 0.21484
# 5063/5063 [==============================] - 53s 10ms/step - loss: 0.0472 - accuracy: 0.9827 - val_loss: 0.2716 - val_accuracy: 0.9382 - lr: 5.0000e-04
# Epoch 13/30
# 5063/5063 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9864
# Epoch 13: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 13: val_accuracy did not improve from 0.93817
#
# Epoch 13: val_loss did not improve from 0.21484
# 5063/5063 [==============================] - 51s 10ms/step - loss: 0.0374 - accuracy: 0.9864 - val_loss: 0.3098 - val_accuracy: 0.9360 - lr: 5.0000e-04
# Epoch 14/30
# 5059/5063 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9881
# Epoch 14: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 14: val_accuracy did not improve from 0.93817
#
# Epoch 14: val_loss did not improve from 0.21484
# 5063/5063 [==============================] - 51s 10ms/step - loss: 0.0321 - accuracy: 0.9881 - val_loss: 0.3257 - val_accuracy: 0.9357 - lr: 5.0000e-04
# Epoch 15/30
# 5063/5063 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9896
# Epoch 15: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 15: val_accuracy improved from 0.93817 to 0.93900, saving model to tmp/checkpoint\own_augmentedAcc.hdf5
#
# Epoch 15: val_loss did not improve from 0.21484
# 5063/5063 [==============================] - 135s 27ms/step - loss: 0.0288 - accuracy: 0.9896 - val_loss: 0.3272 - val_accuracy: 0.9390 - lr: 5.0000e-04
# Epoch 16/30
# 5059/5063 [============================>.] - ETA: 0s - loss: 0.0256 - accuracy: 0.9907
# Epoch 16: saving model to tmp/checkpoint\own_augmented.hdf5
#
# Epoch 16: val_accuracy did not improve from 0.93900
#
# Epoch 16: val_loss did not improve from 0.21484
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Restoring model weights from the end of the best epoch: 6.
# 5063/5063 [==============================] - 74s 15ms/step - loss: 0.0256 - accuracy: 0.9907 - val_loss: 0.3659 - val_accuracy: 0.9360 - lr: 5.0000e-04
# Epoch 16: early stopping

# %%
import visualkeras
from PIL import ImageFont
visualkeras.layered_view(own_augmented_model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=576x175>

# %%
max_val_acc_epoch = np.argmax(list(history_augmented.history['val_accuracy']))+1
max_val_loss_epoch = np.argmin(list(history_augmented.history['val_loss']))+1
epochs = range(1, len(history_augmented.history['accuracy']) + 1)
plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,history_augmented.history['accuracy'], label='Train')
plt.plot(epochs,history_augmented.history['val_accuracy'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,history_augmented.history['loss'], label='Train')
plt.plot(epochs,history_augmented.history['val_loss'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# evaluating baseline coarse model
print(own_augmented_model.evaluate(x_test, y_test))
own_augmented_model.load_weights('tmp/checkpoint/own_augmentedAcc.hdf5')
scoreAcc = own_augmented_model.evaluate(x_test, y_test)
own_augmented_model.load_weights('tmp/checkpoint/own_augmentedLoss.hdf5')
scoreLoss = own_augmented_model.evaluate(x_test, y_test)
print('Best Acc Test Loss:', scoreAcc[0])
print('Best Acc Test Accuracy:', round(scoreAcc[1],4)*100,'%')
print('Best Loss Test Loss:', scoreLoss[0])
print('Best Loss Test Accuracy:', round(scoreLoss[1],4)*100,'%')
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2271 - accuracy: 0.9264
# [0.22711743414402008, 0.9264000058174133]
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3579 - accuracy: 0.9326
# 313/313 [==============================] - 2s 5ms/step - loss: 0.2271 - accuracy: 0.9264
# Best Acc Test Loss: 0.357862651348114
# Best Acc Test Accuracy: 93.26 %
# Best Loss Test Loss: 0.22711743414402008
# Best Loss Test Accuracy: 92.64 %

# %%
own_augmented_model.save_weights("./tmp/fashion-own-augmented-model.h5")

# %% [markdown]
# ## Hyperparameter tuning

# %%
def model_builder(hp):
  model = keras.Sequential()
  model.add(keras.layers.Conv2D(32, (3,3), activation="relu", input_shape=(28, 28, 1))), 
  # model.add(keras.layers.Flatten()),
  model.add(keras.layers.Conv2D(64, (3,3), activation="relu")),  
  model.add(keras.layers.BatchNormalization()),
  model.add(keras.layers.MaxPooling2D((2, 2))),
  model.add(keras.layers.Conv2D(64, (3,3), activation="relu")),
  model.add(keras.layers.Conv2D(64, (3,3), activation="relu")),  
  model.add(keras.layers.BatchNormalization()),  
  model.add(keras.layers.MaxPooling2D((2, 2))),
  model.add(keras.layers.Dropout(0.2)),
  model.add(keras.layers.Flatten()), # 2d to 1d
  model.add(keras.layers.Dense(64, activation="relu")),
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  model.add(keras.layers.Dense(units=hp_units, activation='relu'))
  model.add(keras.layers.Dense(10))

  # Tune the learning rate for the optimizer
  # Choose an optimal value from 0.01, 0.001, or 0.0001
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  return model

# %%
import keras_tuner as kt
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project my_dir\intro_to_kt\oracle.json
# INFO:tensorflow:Reloading Tuner from my_dir\intro_to_kt\tuner0.json

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5)

# %%
tuner.search(x_train, y_train, epochs=50, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# Trial 42 Complete [00h 02m 44s]
# val_accuracy: 0.9240740537643433
#
# Best val_accuracy So Far: 0.9271296262741089
# Total elapsed time: 00h 14m 58s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 288 and the optimal learning rate for the optimizer
# is 0.001.

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(x_train, y_train, epochs=20, validation_split=0.2)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/20
# 1350/1350 [==============================] - 16s 11ms/step - loss: 0.4640 - accuracy: 0.8292 - val_loss: 0.3608 - val_accuracy: 0.8659
# Epoch 2/20
# 1350/1350 [==============================] - 16s 11ms/step - loss: 0.3165 - accuracy: 0.8838 - val_loss: 0.3358 - val_accuracy: 0.8812
# Epoch 3/20
# 1350/1350 [==============================] - 16s 11ms/step - loss: 0.2673 - accuracy: 0.9025 - val_loss: 0.2996 - val_accuracy: 0.8961
# Epoch 4/20
# 1350/1350 [==============================] - 16s 12ms/step - loss: 0.2410 - accuracy: 0.9108 - val_loss: 0.2990 - val_accuracy: 0.8959
# Epoch 5/20
# 1350/1350 [==============================] - 16s 12ms/step - loss: 0.2191 - accuracy: 0.9178 - val_loss: 0.3030 - val_accuracy: 0.8898
# Epoch 6/20
# 1350/1350 [==============================] - 15s 11ms/step - loss: 0.2025 - accuracy: 0.9251 - val_loss: 0.2657 - val_accuracy: 0.9094
# Epoch 7/20
# 1350/1350 [==============================] - 15s 11ms/step - loss: 0.1840 - accuracy: 0.9310 - val_loss: 0.2422 - val_accuracy: 0.9179
# Epoch 8/20
# 1350/1350 [==============================] - 16s 11ms/step - loss: 0.1693 - accuracy: 0.9362 - val_loss: 0.2549 - val_accuracy: 0.9105
# Epoch 9/20
# 1350/1350 [==============================] - 16s 12ms/step - loss: 0.1597 - accuracy: 0.9403 - val_loss: 0.2548 - val_accuracy: 0.9164
# Epoch 10/20
# 1350/1350 [==============================] - 15s 11ms/step - loss: 0.1464 - accuracy: 0.9452 - val_loss: 0.2442 - val_accuracy: 0.9205
# Epoch 11/20
# 1350/1350 [==============================] - 15s 11ms/step - loss: 0.1370 - accuracy: 0.9490 - val_loss: 0.2478 - val_accuracy: 0.9193
# Epoch 12/20
# 1350/1350 [==============================] - 15s 11ms/step - loss: 0.1314 - accuracy: 0.9523 - val_loss: 0.2451 - val_accuracy: 0.9242
# Epoch 13/20
# 1350/1350 [==============================] - 15s 11ms/step - loss: 0.1215 - accuracy: 0.9536 - val_loss: 0.2662 - val_accuracy: 0.9239
# Epoch 14/20
# 1350/1350 [==============================] - 15s 11ms/step - loss: 0.1152 - accuracy: 0.9569 - val_loss: 0.2761 - val_accuracy: 0.9204
# Epoch 15/20
# 1350/1350 [==============================] - 15s 11ms/step - loss: 0.1053 - accuracy: 0.9599 - val_loss: 0.2724 - val_accuracy: 0.9194
# Epoch 16/20
# 1350/1350 [==============================] - 15s 11ms/step - loss: 0.1000 - accuracy: 0.9639 - val_loss: 0.2715 - val_accuracy: 0.9250
# Epoch 17/20
# 1350/1350 [==============================] - 16s 12ms/step - loss: 0.0968 - accuracy: 0.9643 - val_loss: 0.2767 - val_accuracy: 0.9194
# Epoch 18/20
# 1350/1350 [==============================] - 15s 11ms/step - loss: 0.0909 - accuracy: 0.9660 - val_loss: 0.2874 - val_accuracy: 0.9273
# Epoch 19/20
# 1350/1350 [==============================] - 15s 11ms/step - loss: 0.0809 - accuracy: 0.9698 - val_loss: 0.2916 - val_accuracy: 0.9242
# Epoch 20/20
# 1350/1350 [==============================] - 16s 12ms/step - loss: 0.0835 - accuracy: 0.9689 - val_loss: 0.2975 - val_accuracy: 0.9241
# Best epoch: 18

# %%
hypermodel = tuner.hypermodel.build(best_hps)
hypermodel.summary()
# Retrain the model
checkpoint = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/hyper.hdf5',verbose=True)
getAcc = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/hyperAcc.hdf5',verbose=True,save_best_only=True,monitor='val_accuracy')
getLoss = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/hyperLoss.hdf5',verbose=True,save_best_only=True,monitor='val_loss')
hypermodel_history = hypermodel.fit(x_train, y_train, 
                                                epochs=20, 
                                                validation_data=(x_test, y_test), 
                                                callbacks=[checkpoint,getAcc,getLoss, 
                                                EarlyStopping(monitor='val_accuracy', mode='max',patience=5)])
hypermodel_history
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_9 (Conv2D)           (None, 24, 24, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 10, 10, 64)        36928
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 64)          36928
#
#  batch_normalization_5 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 64)          0
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_6 (Dense)             (None, 64)                65600
#
#  dense_7 (Dense)             (None, 288)               18720
#
#  dense_8 (Dense)             (None, 10)                2890
#
# =================================================================
# Total params: 180,394
# Trainable params: 180,138
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/20
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.4377 - accuracy: 0.8387
# Epoch 1: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 1: val_accuracy improved from -inf to 0.87750, saving model to tmp/checkpoint\hyperAcc.hdf5
#
# Epoch 1: val_loss improved from inf to 0.34082, saving model to tmp/checkpoint\hyperLoss.hdf5
# 1688/1688 [==============================] - 21s 12ms/step - loss: 0.4375 - accuracy: 0.8388 - val_loss: 0.3408 - val_accuracy: 0.8775
# Epoch 2/20
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.2950 - accuracy: 0.8918
# Epoch 2: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 2: val_accuracy improved from 0.87750 to 0.89220, saving model to tmp/checkpoint\hyperAcc.hdf5
#
# Epoch 2: val_loss improved from 0.34082 to 0.29246, saving model to tmp/checkpoint\hyperLoss.hdf5
# 1688/1688 [==============================] - 19s 11ms/step - loss: 0.2948 - accuracy: 0.8919 - val_loss: 0.2925 - val_accuracy: 0.8922
# Epoch 3/20
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.2549 - accuracy: 0.9071
# Epoch 3: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 3: val_accuracy improved from 0.89220 to 0.89330, saving model to tmp/checkpoint\hyperAcc.hdf5
#
# Epoch 3: val_loss did not improve from 0.29246
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.2549 - accuracy: 0.9071 - val_loss: 0.2952 - val_accuracy: 0.8933
# Epoch 4/20
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.2241 - accuracy: 0.9170
# Epoch 4: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 4: val_accuracy improved from 0.89330 to 0.90860, saving model to tmp/checkpoint\hyperAcc.hdf5
#
# Epoch 4: val_loss improved from 0.29246 to 0.25909, saving model to tmp/checkpoint\hyperLoss.hdf5
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.2241 - accuracy: 0.9169 - val_loss: 0.2591 - val_accuracy: 0.9086
# Epoch 5/20
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.2045 - accuracy: 0.9243
# Epoch 5: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 5: val_accuracy improved from 0.90860 to 0.91840, saving model to tmp/checkpoint\hyperAcc.hdf5
#
# Epoch 5: val_loss improved from 0.25909 to 0.23083, saving model to tmp/checkpoint\hyperLoss.hdf5
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.2045 - accuracy: 0.9244 - val_loss: 0.2308 - val_accuracy: 0.9184
# Epoch 6/20
# 1685/1688 [============================>.] - ETA: 0s - loss: 0.1884 - accuracy: 0.9301
# Epoch 6: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 6: val_accuracy improved from 0.91840 to 0.91880, saving model to tmp/checkpoint\hyperAcc.hdf5
#
# Epoch 6: val_loss improved from 0.23083 to 0.22716, saving model to tmp/checkpoint\hyperLoss.hdf5
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.1885 - accuracy: 0.9301 - val_loss: 0.2272 - val_accuracy: 0.9188
# Epoch 7/20
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1742 - accuracy: 0.9348
# Epoch 7: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 7: val_accuracy improved from 0.91880 to 0.91950, saving model to tmp/checkpoint\hyperAcc.hdf5
#
# Epoch 7: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 21s 12ms/step - loss: 0.1743 - accuracy: 0.9348 - val_loss: 0.2459 - val_accuracy: 0.9195
# Epoch 8/20
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.1607 - accuracy: 0.9412
# Epoch 8: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 8: val_accuracy improved from 0.91950 to 0.92150, saving model to tmp/checkpoint\hyperAcc.hdf5
#
# Epoch 8: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 22s 13ms/step - loss: 0.1609 - accuracy: 0.9412 - val_loss: 0.2282 - val_accuracy: 0.9215
# Epoch 9/20
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.1487 - accuracy: 0.9444
# Epoch 9: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 9: val_accuracy did not improve from 0.92150
#
# Epoch 9: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 23s 14ms/step - loss: 0.1487 - accuracy: 0.9444 - val_loss: 0.2342 - val_accuracy: 0.9187
# Epoch 10/20
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1381 - accuracy: 0.9489
# Epoch 10: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 10: val_accuracy did not improve from 0.92150
#
# Epoch 10: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 22s 13ms/step - loss: 0.1383 - accuracy: 0.9489 - val_loss: 0.2383 - val_accuracy: 0.9197
# Epoch 11/20
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.1282 - accuracy: 0.9513
# Epoch 11: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 11: val_accuracy did not improve from 0.92150
#
# Epoch 11: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.1281 - accuracy: 0.9514 - val_loss: 0.2647 - val_accuracy: 0.9188
# Epoch 12/20
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.9548
# Epoch 12: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 12: val_accuracy improved from 0.92150 to 0.92540, saving model to tmp/checkpoint\hyperAcc.hdf5
#
# Epoch 12: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.1204 - accuracy: 0.9548 - val_loss: 0.2456 - val_accuracy: 0.9254
# Epoch 13/20
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.1134 - accuracy: 0.9579
# Epoch 13: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 13: val_accuracy improved from 0.92540 to 0.92580, saving model to tmp/checkpoint\hyperAcc.hdf5
#
# Epoch 13: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.1136 - accuracy: 0.9579 - val_loss: 0.2537 - val_accuracy: 0.9258
# Epoch 14/20
# 1688/1688 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9603
# Epoch 14: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 14: val_accuracy did not improve from 0.92580
#
# Epoch 14: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.1060 - accuracy: 0.9603 - val_loss: 0.2604 - val_accuracy: 0.9247
# Epoch 15/20
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.1000 - accuracy: 0.9631
# Epoch 15: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 15: val_accuracy did not improve from 0.92580
#
# Epoch 15: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.1001 - accuracy: 0.9631 - val_loss: 0.2768 - val_accuracy: 0.9217
# Epoch 16/20
# 1684/1688 [============================>.] - ETA: 0s - loss: 0.0953 - accuracy: 0.9637
# Epoch 16: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 16: val_accuracy did not improve from 0.92580
#
# Epoch 16: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.0953 - accuracy: 0.9636 - val_loss: 0.2610 - val_accuracy: 0.9236
# Epoch 17/20
# 1686/1688 [============================>.] - ETA: 0s - loss: 0.0890 - accuracy: 0.9668
# Epoch 17: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 17: val_accuracy did not improve from 0.92580
#
# Epoch 17: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 21s 12ms/step - loss: 0.0890 - accuracy: 0.9668 - val_loss: 0.2831 - val_accuracy: 0.9213
# Epoch 18/20
# 1687/1688 [============================>.] - ETA: 0s - loss: 0.0852 - accuracy: 0.9687
# Epoch 18: saving model to tmp/checkpoint\hyper.hdf5
#
# Epoch 18: val_accuracy did not improve from 0.92580
#
# Epoch 18: val_loss did not improve from 0.22716
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.0853 - accuracy: 0.9687 - val_loss: 0.2924 - val_accuracy: 0.9214

# %%
# evaluating baseline coarse model
print(hypermodel.evaluate(x_test, y_test))
hypermodel.load_weights('tmp/checkpoint/hyperAcc.hdf5')
scoreAcc = hypermodel.evaluate(x_test, y_test)
hypermodel.load_weights('tmp/checkpoint/hyperLoss.hdf5')
scoreLoss = hypermodel.evaluate(x_test, y_test)
print('Best Acc Test Loss:', scoreAcc[0])
print('Best Acc Test Accuracy:', round(scoreAcc[1],4)*100,'%')
print('Best Loss Test Loss:', scoreLoss[0])
print('Best Loss Test Accuracy:', round(scoreLoss[1],4)*100,'%')
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2924 - accuracy: 0.9214
# [0.2924066185951233, 0.9214000105857849]
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2537 - accuracy: 0.9258
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2272 - accuracy: 0.9188
# Best Acc Test Loss: 0.2537296414375305
# Best Acc Test Accuracy: 92.58 %
# Best Loss Test Loss: 0.22716176509857178
# Best Loss Test Accuracy: 91.88 %

# %%
max_val_acc_epoch = np.argmax(list(hypermodel_history.history['val_accuracy']))+1
max_val_loss_epoch = np.argmin(list(hypermodel_history.history['val_loss']))+1
epochs = range(1, len(hypermodel_history.history['accuracy']) + 1)
plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,hypermodel_history.history['accuracy'], label='Train')
plt.plot(epochs,hypermodel_history.history['val_accuracy'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,hypermodel_history.history['loss'], label='Train')
plt.plot(epochs,hypermodel_history.history['val_loss'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import visualkeras
from PIL import ImageFont
visualkeras.layered_view(hypermodel, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x201>

# %%
hypermodel.save_weights("./tmp/fashion_hyper_model.h5")

# %%
tuner.search(x_train_augmented, y_train_augmented, epochs=50, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 288 and the optimal learning rate for the optimizer
# is 0.001.

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(x_train_augmented, y_train_augmented, epochs=30, validation_split=0.2)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/30
# 4050/4050 [==============================] - 53s 13ms/step - loss: 0.3848 - accuracy: 0.8583 - val_loss: 0.3432 - val_accuracy: 0.8776
# Epoch 2/30
# 4050/4050 [==============================] - 42s 10ms/step - loss: 0.2681 - accuracy: 0.9018 - val_loss: 0.3154 - val_accuracy: 0.8856
# Epoch 3/30
# 4050/4050 [==============================] - 41s 10ms/step - loss: 0.2324 - accuracy: 0.9148 - val_loss: 0.2739 - val_accuracy: 0.8994
# Epoch 4/30
# 4050/4050 [==============================] - 43s 11ms/step - loss: 0.2083 - accuracy: 0.9238 - val_loss: 0.2768 - val_accuracy: 0.8954
# Epoch 5/30
# 4050/4050 [==============================] - 44s 11ms/step - loss: 0.1892 - accuracy: 0.9303 - val_loss: 0.2575 - val_accuracy: 0.9076
# Epoch 6/30
# 4050/4050 [==============================] - 49s 12ms/step - loss: 0.1737 - accuracy: 0.9351 - val_loss: 0.2361 - val_accuracy: 0.9139
# Epoch 7/30
# 4050/4050 [==============================] - 51s 12ms/step - loss: 0.1604 - accuracy: 0.9408 - val_loss: 0.2840 - val_accuracy: 0.9020
# Epoch 8/30
# 4050/4050 [==============================] - 50s 12ms/step - loss: 0.1501 - accuracy: 0.9445 - val_loss: 0.2338 - val_accuracy: 0.9153
# Epoch 9/30
# 4050/4050 [==============================] - 49s 12ms/step - loss: 0.1411 - accuracy: 0.9474 - val_loss: 0.2460 - val_accuracy: 0.9112
# Epoch 10/30
# 4050/4050 [==============================] - 49s 12ms/step - loss: 0.1331 - accuracy: 0.9504 - val_loss: 0.2465 - val_accuracy: 0.9112
# Epoch 11/30
# 4050/4050 [==============================] - 51s 12ms/step - loss: 0.1259 - accuracy: 0.9528 - val_loss: 0.2271 - val_accuracy: 0.9199
# Epoch 12/30
# 4050/4050 [==============================] - 50s 12ms/step - loss: 0.1192 - accuracy: 0.9562 - val_loss: 0.2344 - val_accuracy: 0.9193
# Epoch 13/30
# 4050/4050 [==============================] - 51s 13ms/step - loss: 0.1132 - accuracy: 0.9579 - val_loss: 0.2318 - val_accuracy: 0.9182
# Epoch 14/30
# 4050/4050 [==============================] - 50s 12ms/step - loss: 0.1064 - accuracy: 0.9602 - val_loss: 0.2247 - val_accuracy: 0.9230
# Epoch 15/30
# 4050/4050 [==============================] - 46s 11ms/step - loss: 0.1020 - accuracy: 0.9617 - val_loss: 0.2214 - val_accuracy: 0.9267
# Epoch 16/30
# 4050/4050 [==============================] - 46s 11ms/step - loss: 0.0975 - accuracy: 0.9642 - val_loss: 0.2348 - val_accuracy: 0.9219
# Epoch 17/30
# 4050/4050 [==============================] - 48s 12ms/step - loss: 0.0934 - accuracy: 0.9647 - val_loss: 0.2275 - val_accuracy: 0.9261
# Epoch 18/30
# 4050/4050 [==============================] - 47s 12ms/step - loss: 0.0903 - accuracy: 0.9664 - val_loss: 0.2264 - val_accuracy: 0.9236
# Epoch 19/30
# 4050/4050 [==============================] - 47s 11ms/step - loss: 0.0839 - accuracy: 0.9696 - val_loss: 0.2365 - val_accuracy: 0.9215
# Epoch 20/30
# 4050/4050 [==============================] - 46s 11ms/step - loss: 0.0813 - accuracy: 0.9703 - val_loss: 0.2300 - val_accuracy: 0.9271
# Epoch 21/30
# 4050/4050 [==============================] - 47s 12ms/step - loss: 0.0781 - accuracy: 0.9711 - val_loss: 0.2412 - val_accuracy: 0.9259
# Epoch 22/30
# 4050/4050 [==============================] - 48s 12ms/step - loss: 0.0763 - accuracy: 0.9724 - val_loss: 0.2433 - val_accuracy: 0.9269
# Epoch 23/30
# 4050/4050 [==============================] - 48s 12ms/step - loss: 0.0723 - accuracy: 0.9739 - val_loss: 0.2523 - val_accuracy: 0.9217
# Epoch 24/30
# 4050/4050 [==============================] - 47s 12ms/step - loss: 0.0713 - accuracy: 0.9732 - val_loss: 0.2422 - val_accuracy: 0.9249
# Epoch 25/30
# 4050/4050 [==============================] - 46s 11ms/step - loss: 0.0690 - accuracy: 0.9745 - val_loss: 0.2523 - val_accuracy: 0.9260
# Epoch 26/30
# 4050/4050 [==============================] - 46s 11ms/step - loss: 0.0655 - accuracy: 0.9759 - val_loss: 0.2353 - val_accuracy: 0.9292
# Epoch 27/30
# 4050/4050 [==============================] - 47s 12ms/step - loss: 0.0650 - accuracy: 0.9767 - val_loss: 0.2373 - val_accuracy: 0.9289
# Epoch 28/30
# 4050/4050 [==============================] - 48s 12ms/step - loss: 0.0625 - accuracy: 0.9772 - val_loss: 0.2513 - val_accuracy: 0.9262
# Epoch 29/30
# 4050/4050 [==============================] - 48s 12ms/step - loss: 0.0607 - accuracy: 0.9773 - val_loss: 0.2980 - val_accuracy: 0.9218
# Epoch 30/30
# 4050/4050 [==============================] - 50s 12ms/step - loss: 0.0587 - accuracy: 0.9786 - val_loss: 0.2474 - val_accuracy: 0.9294
# Best epoch: 30

# %%
hypermodel_augmented = tuner.hypermodel.build(best_hps)
hypermodel_augmented.summary()
checkpoint = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/hypermodelAugmented.hdf5',verbose=True)
getAcc = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/hypermodelAugmentedAcc.hdf5',verbose=True,save_best_only=True,monitor='val_accuracy')
getLoss = tf.keras.callbacks.ModelCheckpoint('tmp/checkpoint/hypermodelAugmentedLoss.hdf5',verbose=True,save_best_only=True,monitor='val_loss')
hypermodel_augmented_history = hypermodel_augmented.fit(x_train_augmented, y_train_augmented, 
                                                epochs=30, 
                                                validation_data=(x_test, y_test), 
                                                callbacks=[checkpoint,getAcc,getLoss, 
                                                EarlyStopping(monitor='val_accuracy', mode='max',patience=10)])
hypermodel_augmented_history
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 26, 26, 32)        320
#
#  conv2d_21 (Conv2D)          (None, 24, 24, 64)        18496
#
#  batch_normalization_10 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 10, 10, 64)        36928
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 64)          36928
#
#  batch_normalization_11 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 4, 4, 64)          0
#
#  flatten_5 (Flatten)         (None, 1024)              0
#
#  dense_15 (Dense)            (None, 64)                65600
#
#  dense_16 (Dense)            (None, 288)               18720
#
#  dense_17 (Dense)            (None, 10)                2890
#
# =================================================================
# Total params: 180,394
# Trainable params: 180,138
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/30
# 5060/5063 [============================>.] - ETA: 0s - loss: 0.3839 - accuracy: 0.8571
# Epoch 1: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 1: val_accuracy improved from -inf to 0.89190, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 1: val_loss improved from inf to 0.29631, saving model to tmp/checkpoint\hypermodelAugmentedLoss.hdf5
# 5063/5063 [==============================] - 62s 12ms/step - loss: 0.3839 - accuracy: 0.8571 - val_loss: 0.2963 - val_accuracy: 0.8919
# Epoch 2/30
# 5059/5063 [============================>.] - ETA: 0s - loss: 0.2676 - accuracy: 0.9015
# Epoch 2: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 2: val_accuracy improved from 0.89190 to 0.91230, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 2: val_loss improved from 0.29631 to 0.24203, saving model to tmp/checkpoint\hypermodelAugmentedLoss.hdf5
# 5063/5063 [==============================] - 59s 12ms/step - loss: 0.2677 - accuracy: 0.9015 - val_loss: 0.2420 - val_accuracy: 0.9123
# Epoch 3/30
# 5062/5063 [============================>.] - ETA: 0s - loss: 0.2330 - accuracy: 0.9143
# Epoch 3: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 3: val_accuracy improved from 0.91230 to 0.91810, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 3: val_loss improved from 0.24203 to 0.23232, saving model to tmp/checkpoint\hypermodelAugmentedLoss.hdf5
# 5063/5063 [==============================] - 57s 11ms/step - loss: 0.2330 - accuracy: 0.9143 - val_loss: 0.2323 - val_accuracy: 0.9181
# Epoch 4/30
# 5061/5063 [============================>.] - ETA: 0s - loss: 0.2086 - accuracy: 0.9233
# Epoch 4: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 4: val_accuracy improved from 0.91810 to 0.91840, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 4: val_loss improved from 0.23232 to 0.22974, saving model to tmp/checkpoint\hypermodelAugmentedLoss.hdf5
# 5063/5063 [==============================] - 53s 10ms/step - loss: 0.2086 - accuracy: 0.9233 - val_loss: 0.2297 - val_accuracy: 0.9184
# Epoch 5/30
# 5062/5063 [============================>.] - ETA: 0s - loss: 0.1917 - accuracy: 0.9295
# Epoch 5: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 5: val_accuracy improved from 0.91840 to 0.92180, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 5: val_loss improved from 0.22974 to 0.22413, saving model to tmp/checkpoint\hypermodelAugmentedLoss.hdf5
# 5063/5063 [==============================] - 52s 10ms/step - loss: 0.1917 - accuracy: 0.9295 - val_loss: 0.2241 - val_accuracy: 0.9218
# Epoch 6/30
# 5058/5063 [============================>.] - ETA: 0s - loss: 0.1787 - accuracy: 0.9332
# Epoch 6: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 6: val_accuracy improved from 0.92180 to 0.92640, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 6: val_loss improved from 0.22413 to 0.21792, saving model to tmp/checkpoint\hypermodelAugmentedLoss.hdf5
# 5063/5063 [==============================] - 54s 11ms/step - loss: 0.1787 - accuracy: 0.9332 - val_loss: 0.2179 - val_accuracy: 0.9264
# Epoch 7/30
# 5062/5063 [============================>.] - ETA: 0s - loss: 0.1674 - accuracy: 0.9375
# Epoch 7: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 7: val_accuracy improved from 0.92640 to 0.92800, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 7: val_loss improved from 0.21792 to 0.21447, saving model to tmp/checkpoint\hypermodelAugmentedLoss.hdf5
# 5063/5063 [==============================] - 55s 11ms/step - loss: 0.1674 - accuracy: 0.9375 - val_loss: 0.2145 - val_accuracy: 0.9280
# Epoch 8/30
# 5060/5063 [============================>.] - ETA: 0s - loss: 0.1566 - accuracy: 0.9414
# Epoch 8: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 8: val_accuracy improved from 0.92800 to 0.92870, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 8: val_loss improved from 0.21447 to 0.21311, saving model to tmp/checkpoint\hypermodelAugmentedLoss.hdf5
# 5063/5063 [==============================] - 54s 11ms/step - loss: 0.1566 - accuracy: 0.9414 - val_loss: 0.2131 - val_accuracy: 0.9287
# Epoch 9/30
# 5062/5063 [============================>.] - ETA: 0s - loss: 0.1481 - accuracy: 0.9451
# Epoch 9: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 9: val_accuracy did not improve from 0.92870
#
# Epoch 9: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 52s 10ms/step - loss: 0.1481 - accuracy: 0.9450 - val_loss: 0.2405 - val_accuracy: 0.9236
# Epoch 10/30
# 5061/5063 [============================>.] - ETA: 0s - loss: 0.1398 - accuracy: 0.9477
# Epoch 10: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 10: val_accuracy did not improve from 0.92870
#
# Epoch 10: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 58s 11ms/step - loss: 0.1398 - accuracy: 0.9477 - val_loss: 0.2225 - val_accuracy: 0.9263
# Epoch 11/30
# 5061/5063 [============================>.] - ETA: 0s - loss: 0.1326 - accuracy: 0.9503
# Epoch 11: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 11: val_accuracy improved from 0.92870 to 0.93010, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 11: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 60s 12ms/step - loss: 0.1326 - accuracy: 0.9503 - val_loss: 0.2196 - val_accuracy: 0.9301
# Epoch 12/30
# 5061/5063 [============================>.] - ETA: 0s - loss: 0.1267 - accuracy: 0.9523
# Epoch 12: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 12: val_accuracy did not improve from 0.93010
#
# Epoch 12: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 60s 12ms/step - loss: 0.1267 - accuracy: 0.9523 - val_loss: 0.2292 - val_accuracy: 0.9286
# Epoch 13/30
# 5059/5063 [============================>.] - ETA: 0s - loss: 0.1209 - accuracy: 0.9552
# Epoch 13: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 13: val_accuracy did not improve from 0.93010
#
# Epoch 13: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 60s 12ms/step - loss: 0.1209 - accuracy: 0.9552 - val_loss: 0.2300 - val_accuracy: 0.9301
# Epoch 14/30
# 5060/5063 [============================>.] - ETA: 0s - loss: 0.1154 - accuracy: 0.9567
# Epoch 14: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 14: val_accuracy did not improve from 0.93010
#
# Epoch 14: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 61s 12ms/step - loss: 0.1154 - accuracy: 0.9567 - val_loss: 0.2345 - val_accuracy: 0.9299
# Epoch 15/30
# 5060/5063 [============================>.] - ETA: 0s - loss: 0.1120 - accuracy: 0.9581
# Epoch 15: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 15: val_accuracy improved from 0.93010 to 0.93060, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 15: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 61s 12ms/step - loss: 0.1121 - accuracy: 0.9581 - val_loss: 0.2469 - val_accuracy: 0.9306
# Epoch 16/30
# 5061/5063 [============================>.] - ETA: 0s - loss: 0.1058 - accuracy: 0.9601
# Epoch 16: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 16: val_accuracy improved from 0.93060 to 0.93070, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 16: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 57s 11ms/step - loss: 0.1058 - accuracy: 0.9601 - val_loss: 0.2391 - val_accuracy: 0.9307
# Epoch 17/30
# 5059/5063 [============================>.] - ETA: 0s - loss: 0.1022 - accuracy: 0.9614
# Epoch 17: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 17: val_accuracy did not improve from 0.93070
#
# Epoch 17: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 61s 12ms/step - loss: 0.1022 - accuracy: 0.9614 - val_loss: 0.2397 - val_accuracy: 0.9289
# Epoch 18/30
# 5060/5063 [============================>.] - ETA: 0s - loss: 0.0977 - accuracy: 0.9633
# Epoch 18: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 18: val_accuracy improved from 0.93070 to 0.93210, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 18: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 61s 12ms/step - loss: 0.0977 - accuracy: 0.9633 - val_loss: 0.2475 - val_accuracy: 0.9321
# Epoch 19/30
# 5061/5063 [============================>.] - ETA: 0s - loss: 0.0956 - accuracy: 0.9641
# Epoch 19: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 19: val_accuracy improved from 0.93210 to 0.93450, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 19: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 62s 12ms/step - loss: 0.0956 - accuracy: 0.9641 - val_loss: 0.2466 - val_accuracy: 0.9345
# Epoch 20/30
# 5059/5063 [============================>.] - ETA: 0s - loss: 0.0922 - accuracy: 0.9648
# Epoch 20: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 20: val_accuracy did not improve from 0.93450
#
# Epoch 20: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 64s 13ms/step - loss: 0.0922 - accuracy: 0.9648 - val_loss: 0.2726 - val_accuracy: 0.9275
# Epoch 21/30
# 5060/5063 [============================>.] - ETA: 0s - loss: 0.0907 - accuracy: 0.9658
# Epoch 21: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 21: val_accuracy improved from 0.93450 to 0.93550, saving model to tmp/checkpoint\hypermodelAugmentedAcc.hdf5
#
# Epoch 21: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 62s 12ms/step - loss: 0.0908 - accuracy: 0.9658 - val_loss: 0.2595 - val_accuracy: 0.9355
# Epoch 22/30
# 5059/5063 [============================>.] - ETA: 0s - loss: 0.0859 - accuracy: 0.9681
# Epoch 22: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 22: val_accuracy did not improve from 0.93550
#
# Epoch 22: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 61s 12ms/step - loss: 0.0859 - accuracy: 0.9681 - val_loss: 0.2644 - val_accuracy: 0.9302
# Epoch 23/30
# 5062/5063 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9674
# Epoch 23: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 23: val_accuracy did not improve from 0.93550
#
# Epoch 23: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 56s 11ms/step - loss: 0.0871 - accuracy: 0.9674 - val_loss: 0.2449 - val_accuracy: 0.9352
# Epoch 24/30
# 5062/5063 [============================>.] - ETA: 0s - loss: 0.0831 - accuracy: 0.9689
# Epoch 24: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 24: val_accuracy did not improve from 0.93550
#
# Epoch 24: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 53s 10ms/step - loss: 0.0831 - accuracy: 0.9689 - val_loss: 0.2642 - val_accuracy: 0.9319
# Epoch 25/30
# 5062/5063 [============================>.] - ETA: 0s - loss: 0.0801 - accuracy: 0.9701
# Epoch 25: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 25: val_accuracy did not improve from 0.93550
#
# Epoch 25: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 52s 10ms/step - loss: 0.0801 - accuracy: 0.9701 - val_loss: 0.2830 - val_accuracy: 0.9300
# Epoch 26/30
# 5061/5063 [============================>.] - ETA: 0s - loss: 0.0779 - accuracy: 0.9710
# Epoch 26: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 26: val_accuracy did not improve from 0.93550
#
# Epoch 26: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 52s 10ms/step - loss: 0.0779 - accuracy: 0.9710 - val_loss: 0.3051 - val_accuracy: 0.9303
# Epoch 27/30
# 5060/5063 [============================>.] - ETA: 0s - loss: 0.0766 - accuracy: 0.9713
# Epoch 27: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 27: val_accuracy did not improve from 0.93550
#
# Epoch 27: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 52s 10ms/step - loss: 0.0766 - accuracy: 0.9713 - val_loss: 0.3002 - val_accuracy: 0.9335
# Epoch 28/30
# 5063/5063 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9722
# Epoch 28: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 28: val_accuracy did not improve from 0.93550
#
# Epoch 28: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 54s 11ms/step - loss: 0.0744 - accuracy: 0.9722 - val_loss: 0.3251 - val_accuracy: 0.9281
# Epoch 29/30
# 5061/5063 [============================>.] - ETA: 0s - loss: 0.0739 - accuracy: 0.9720
# Epoch 29: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 29: val_accuracy did not improve from 0.93550
#
# Epoch 29: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 52s 10ms/step - loss: 0.0739 - accuracy: 0.9720 - val_loss: 0.3144 - val_accuracy: 0.9300
# Epoch 30/30
# 5060/5063 [============================>.] - ETA: 0s - loss: 0.0717 - accuracy: 0.9736
# Epoch 30: saving model to tmp/checkpoint\hypermodelAugmented.hdf5
#
# Epoch 30: val_accuracy did not improve from 0.93550
#
# Epoch 30: val_loss did not improve from 0.21311
# 5063/5063 [==============================] - 48s 9ms/step - loss: 0.0717 - accuracy: 0.9736 - val_loss: 0.2993 - val_accuracy: 0.9337

# %%
# evaluating baseline coarse model
print(hypermodel_augmented.evaluate(x_test, y_test))
hypermodel_augmented.load_weights('tmp/checkpoint/hypermodelAugmentedAcc.hdf5')
scoreAcc = hypermodel_augmented.evaluate(x_test, y_test)
hypermodel_augmented.load_weights('tmp/checkpoint/hypermodelAugmentedLoss.hdf5')
scoreLoss = hypermodel_augmented.evaluate(x_test, y_test)
print('Best Acc Test Loss:', scoreAcc[0])
print('Best Acc Test Accuracy:', round(scoreAcc[1],4)*100,'%')
print('Best Loss Test Loss:', scoreLoss[0])
print('Best Loss Test Accuracy:', round(scoreLoss[1],4)*100,'%')
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2993 - accuracy: 0.9337
# [0.29934805631637573, 0.9337000250816345]
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2595 - accuracy: 0.9355
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2131 - accuracy: 0.9287
# Best Acc Test Loss: 0.25950169563293457
# Best Acc Test Accuracy: 93.55 %
# Best Loss Test Loss: 0.21311235427856445
# Best Loss Test Accuracy: 92.86999999999999 %

# %%
max_val_acc_epoch = np.argmax(list(hypermodel_augmented_history.history['val_accuracy']))+1
max_val_loss_epoch = np.argmin(list(hypermodel_augmented_history.history['val_loss']))+1
epochs = range(1, len(hypermodel_augmented_history.history['accuracy']) + 1)
plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,hypermodel_augmented_history.history['accuracy'], label='Train')
plt.plot(epochs,hypermodel_augmented_history.history['val_accuracy'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(10,3))
plt.minorticks_on()
plt.axvline(x=max_val_acc_epoch, color='0.5', linestyle='--')
plt.axvline(x=max_val_loss_epoch, color='0.5', linestyle=':')
plt.plot(epochs,hypermodel_augmented_history.history['loss'], label='Train')
plt.plot(epochs,hypermodel_augmented_history.history['val_loss'], label='Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
hypermodel.save_weights("./tmp/fashion_hyper_augmented_model.h5")

# %%
import visualkeras
from PIL import ImageFont
visualkeras.layered_view(hypermodel_augmented, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x201>
